# %% [markdown]
# <a href="https://colab.research.google.com/github/sugarcane-mk/dataPreps_speech/blob/main/Notebooks/dataprep_4_asr_Kaldi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %% [markdown]
# # Segmentation

# %% [markdown]
# The audio files are segmented into individual sentences using `.lab` files, which contain the start and end timestamps for each sentence. These timestamps guide the extraction of specific segments from the audio files, creating individual files for each sentence.

# %%
# !pip install pydub
from pydub import AudioSegment
import IPython.display as ipd
with open('/content/drive/Shareddrives/Audio_ processing/Segmented_data/MSU/label/111-130/111-130(4).lab','r') as f: # <------------------ Path to .lab file --------------------->
  lines = f.readlines()

lines=lines[1::2] # <------------------ Retrives the Necessary timestamps only...! removes silence data labels 's' --------------------->

# # lines=lines[16::2]
# lines=['698200000 730100000 156\n',
#  '730725000 755050000 157\n',
#  '755775000 772900000 158\n',
#  '775700000 806825000 159\n',
#  '873025000 896675000 163\n',
#  '899025000 929325000 164\n',
#  '931575000 949725000 165\n',
#  '951500000 968925000 166\n',
#  '970725000 988625000 167\n',
#  '1004025000 1015350000 169\n',
#  '1017175000 1032500000 170\n',
#  '1033625000 1069875000 171\n',
#  '1071875000 1089875000 172\n',
#  '1090925000 1111325000 173\n',
#  '1114650000 1143300000 174\n',
#  '1144475000 1172450000 175\n',
#  '1198850000 1244250000 177\n',
#  '1247700000 1276600000 178\n',
#  '1278375000 1305800000 179\n',
#  '1307850000 1324325000 180\n']

print('No. of sentences : ', len(lines))

lines
# Out:
# no of sentences :  20
# ['6925000 27100000 111\n',
#  '29450000 50950000 112\n',
#  '53200000 71975000 113\n',
#  '73375000 93050000 114\n',
#  '96550000 122425000 115\n',
#  '134475000 148800000 116\n',
#  '150100000 163700000 117\n',
#  '165475000 177875000 118\n',
#  '180100000 197950000 119\n',
#  '198800000 217500000 120\n',
#  '232675000 249450000 121\n',
#  '251075000 266700000 122\n',
#  '267925000 282325000 123\n',
#  '284275000 301975000 124\n',
#  '303775000 318475000 125\n',
#  '319575000 338525000 126\n',
#  '342500000 361000000 127\n',
#  '364025000 377875000 128\n',
#  '404850000 435450000 129\n',
#  '437375000 466450000 130\n']

# %%
from pydub import AudioSegment
import IPython.display as ipd
import os

audio_file = '/content/drive/Shareddrives/Audio_ processing/Segmented_data/MSU/label/111-130/111-130(4).wav'  # <------------------ Path to corresponding audio file to be splitted --------------------->

# Speaker and session information
speaker = "MSU"       # <------------------ Speaker name to name the splited audio --------------------->
session = 4           # <------------------ Session number/ No. of repetitions --------------------->


for line in lines:
  parts = line.strip().split()
  start_time = float(parts[0]) / 10000
  end_time = float(parts[1]) / 10000
  sentence_number = int(parts[2])

  audio = AudioSegment.from_file(audio_file)
  extracted_audio = audio[start_time:end_time]
  # <------------------ Path to Audio files to be stored --------------------->
  output_file = f"/content/drive/Shareddrives/Audio_ processing/Segmented_data/{speaker}/speech/test/{speaker}_{sentence_number}_{session}.wav"   # MSU_1_1.wav <----Sentence no. retrived from label----->
  os.makedirs(os.path.dirname(output_file), exist_ok=True)
  extracted_audio.export(output_file, format="wav")


print("done")
# Out:
# done

# %%
from pydub import AudioSegment
import IPython.display as ipd
import os

audio_file = '/content/drive/Shareddrives/Audio_ processing/Segmented_data/MSU/label/156-180/156-180(10).wav'

# Speaker and session information
speaker = "MSU"
session = 10


for line in lines:
  parts = line.strip().split()
  start_time = float(parts[0]) / 10000
  end_time = float(parts[1]) / 10000
  sentence_number = int(parts[2])

  audio = AudioSegment.from_file(audio_file)
  extracted_audio = audio[start_time:end_time]

  output_file = f"/content/drive/Shareddrives/Audio_ processing/Segmented_data/{speaker}/speech/156-180/{speaker}_{sentence_number}_{session}.wav"
  os.makedirs(os.path.dirname(output_file), exist_ok=True)
  extracted_audio.export(output_file, format="wav")


print("done")
# Out:
# done

# %% [markdown]
# # Clean & Split Transcripts

# %%
# Creates .txt files for each audio with transcript only

# text/
#   |-  MSU_1_1.txt -> transcript
#   |   ...
#   |_  MSU_180_10.txt -> transcript


import os
import re

def clean_sentence(sentence):
    """
    Removes all symbols from the sentence, keeping only alphanumeric characters and spaces.
    """
    return re.sub(r'[^a-zA-Z0-9\s]', '', sentence)

def generate_copies(input_file, output_folder):
    """
    Generates 10 copies of each sentence, saves them as separate text files,
    and removes symbols from the sentences.
    """
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Read the input file
    with open(input_file, 'r', encoding='utf-8') as file:
        sentences = file.readlines()

    # Process each sentence
    for sentence_number, sentence in enumerate(sentences, start=1):
        # Clean the sentence by removing symbols
        clean_text = clean_sentence(sentence.strip())

        # Generate 10 copies for each sentence
        for copy_number in range(1, 11):
            # Construct the filename
            filename = f"MSU_{sentence_number}_{copy_number}.txt"
            file_path = os.path.join(output_folder, filename)

            # Write the cleaned sentence to the file
            with open(file_path, 'w', encoding='utf-8') as output_file:
                output_file.write(clean_text)

    print(f"Files generated in the folder: {output_folder}")


# Input and output paths
input_file = "/content/transliteration1-197.csv"    # Replace with your input file path <-------------- Text file containing transcripts -------------------->
output_folder = "/content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/text"  # Replace with your desired output folder <-------------- Path to store all the splitted txt files -------------------->

# Run the function
generate_copies(input_file, output_folder)
# Out:
# Files generated in the folder: /content/drive/Shareddrives/Audio_ processing/Segmented_data/MSU/text

# %%
# Creates a .txt with speaker\t transcript <------------------------------ spk_2_utt.txt ---------------------------------->

# output.txt

# MSR_1_1 transcript
# MSR_1_2 transcript
# ....
# MSR_180_10 transcript

import os
import re

def clean_sentence(sentence):
    """
    Removes all symbols from the sentence, keeping only alphanumeric characters and spaces.
    """
    return re.sub(r'[^a-zA-Z0-9\s]', '', sentence)

def generate_copies(input_file, output_folder):
    """
    Generates 10 copies of each sentence, saves them as separate text files,
    and removes symbols from the sentences.
    """
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Read the input file
    with open(input_file, 'r', encoding='utf-8') as file:
        sentences = file.readlines()

    # Process each sentence
    for sentence_number, sentence in enumerate(sentences, start=1):
        # Clean the sentence by removing symbols
        clean_text = clean_sentence(sentence.strip())

        # Generate 10 copies for each sentence
        for copy_number in range(1, 11):                                                  # <-------------- Loop to create 10 copies of each transcript -------------------->
            # Construct the filename
            filename = "spk_2_utt.txt"                                                    # <-------------- Spk_2_utt.txt File name of the text file -------------------->
            file_path = os.path.join(output_folder, filename)

            # Write the cleaned sentence to the file
            with open(file_path, 'a', encoding='utf-8') as output_file:
                output_file.write(f"MSR_{sentence_number}_{copy_number}\t{clean_text}\n") # <------------------ Enter the speaker ID --------------------->

    print(f"Files generated in the folder: {output_folder}")


# Input and output paths
input_file = "/content/drive/Shareddrives/Audio_ processing/transctipts_200.txt"          # <-------------- Text file containing transcripts --------------------> Replace with your input file path
output_folder = "/content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR"  # <-------------- Path to store the spk2utt file --------------------> Replace with your desired output folder

# Run the function
generate_copies(input_file, output_folder)
# Out:
# Files generated in the folder: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR

# %% [markdown]
# ## Split spk2utt

# %%
# to split each sentence in a spk_2_utt.txt file into seperate text files the file name should be the first word of sentence

# text/
#       MSR_1_1.txt -> MSR_1_1  transcript
#       MSR_1_2.txt -> MSR_1_2  transcript
#       .....
#       MSR_180_10.txt -> MSR_180_10  transcript

import re
import os

def split_sentences_into_files(input_filepath, output_folder):
    """
    Splits sentences from a text file into separate files,
    using the first word of each sentence as the filename.
    """
    try:
        with open(input_filepath, 'r', encoding='utf-8') as infile:
            for line in infile:
                sentence = line.strip()
                if not sentence:  # Skip empty lines
                    continue

                words = sentence.split()
                if not words: # Skip lines with no words
                    continue

                filename = words[0]
                # Sanitize the filename to remove invalid characters
                filename = re.sub(r'[\\/*?:"<>|]', "", filename)

                filepath = os.path.join(output_folder, f"{filename}.txt")

                with open(filepath, 'w', encoding='utf-8') as outfile:
                    outfile.write(sentence)
        print(f"Sentences split into files in: {output_folder}")

    except FileNotFoundError:
        print(f"Error: Input file not found at {input_filepath}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:
input_file = "/content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/spk_2_utt.txt"     # <-------------- Path to spk_2 utt.txt files -------------------->
output_directory = "/content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/prompts"     # <-------------- Path to store all the splitted txt files -------------------->

# Create the output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

split_sentences_into_files(input_file, output_directory)
# Out:
# Sentences split into files in: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/prompts

# %% [markdown]
# # Lexicon generation

# %% [markdown]
# ### UniQue word Identification

# %%
# Unique words

import re
import os

def process_text_files(input_filepath, output_filepath):
    """
    Processes text files to remove unwanted symbols, split into words,
    and store unique words in a new text file.
    """
    unique_words = set()

    try:
        with open(input_filepath, 'r', encoding='utf-8') as infile:
            for line in infile:
                # Remove unwanted symbols (keep alphanumeric and spaces)
                cleaned_line = re.sub(r'[^\w\s]', '', line).lower()  # Convert to lowercase

                # Split the line into words
                words = cleaned_line.split()

                # Add unique words to the set
                unique_words.update(words)

        # Write unique words to the output file
        with open(output_filepath, 'w', encoding='utf-8') as outfile:
            for word in sorted(unique_words):  # Sort for better readability
                outfile.write(word + '\n')

        print(f"Unique words saved to: {output_filepath}")

    except FileNotFoundError:
        print(f"Error: Input file not found at {input_filepath}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:  Replace with your actual file paths
input_file = "/content/drive/Shareddrives/Audio_ processing/transctipts_200.txt"                      # <------------------ Input file containing transcripts ----------------->
output_file = "/content/drive/Shareddrives/Audio_ processing/unique_words_200.txt"                    # <------------------ Output file to store unique words in transcripts --------------->

process_text_files(input_file, output_file)
# Out:
# Unique words saved to: /content/drive/Shareddrives/Audio_ processing/unique_words_200.txt

# %% [markdown]
# ### Extract only new words by comparing with existing lexicon

# %%
# i have file 1 and file 2 .txt i need to compare  words in file 1 with the 1st word in file 2 and to display the unmatches words in file 1

def compare_words(file1_path, file2_path):
    """
    Compares words in file1 with the first word in file2 and displays unmatched words from file1.
    """
    try:
        with open(file1_path, 'r', encoding='utf-8') as file1, open(file2_path, 'r', encoding='utf-8') as file2:
            file1_words = set()
            for line in file1:
                words = line.strip().split()  # Split each line into words
                file1_words.update(words)

            first_word_file2 = file2.readline().strip().split()[0] # Get only the 1st word in file2

            unmatched_words = file1_words - set([first_word_file2]) #difference between file1 and file2

            for word in unmatched_words:
                print(word)

    except FileNotFoundError:
        print(f"Error: One or both of the files were not found.")
    except Exception as e:
        print(f"An error occurred: {e}")


# Example usage: Replace with your actual file paths
file1_path = "/content/drive/Shareddrives/Audio_ processing/Segmented_data/MSU/unique_words.txt" # <------------------ Path to uniqueWords.txt --------------------->
file2_path = "/content/drive/MyDrive/lexicon.txt"                                                # <------------------ Path to lexicons.txt --------------------->
compare_words(file1_path, file2_path)

# %% [markdown]
# # Phone Dictonary

# %%
# prompt: i have phone list and words  in a txt file i need to split words into phones by  phone list amd save it in a txt file as word \t phonems example aamaa aa m aa here is the phone list aa
# ai
# au
# dx
# ee
# eu
# ii
# lx
# nd
# ng
# nj
# nx
# rx
# sx
# tx
# oo
# uu
# zh
# e
# f
# g
# h
# i
# j
# k
# l
# m
# n
# o
# p
# r
# s
# t
# u
# w
# y
# a
# b
# c
# d

def split_words_into_phones(input_filepath, phone_list_filepath, output_filepath):
    """
    Splits words in a text file into phonemes based on a provided phone list.
    """
    try:
        with open(phone_list_filepath, 'r', encoding='utf-8') as phone_file:
            phone_list = [line.strip() for line in phone_file]

        with open(input_filepath, 'r', encoding='utf-8') as infile, open(output_filepath, 'w', encoding='utf-8') as outfile:
            for line in infile:
                word = line.strip()
                phonemes = []
                for phone in phone_list:  # Iterate through the phone list
                    if phone in word:
                        phonemes.append(phone)

                outfile.write(f"{word}\t{' '.join(phonemes)}\n")  # Write word and phonemes
        print(f"Word-phoneme mapping saved to: {output_filepath}")

    except FileNotFoundError:
        print(f"Error: Input file not found at {input_filepath} or {phone_list_filepath}")
    except Exception as e:
        print(f"An error occurred: {e}")


# Example usage:  Replace with your actual file paths
input_file = "/content/drive/Shareddrives/Audio_ processing/Segmented_data/MSU/unique_words.txt"      # input file
phone_list_file = "/content/drive/MyDrive/lexicon.txt"                                                # phone list file
output_file = "/content/drive/Shareddrives/Audio_ processing/Segmented_data/MSU/word_phonemes.txt"    # output file

split_words_into_phones(input_file, phone_list_file, output_file)
# Out:
# Word-phoneme mapping saved to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/MSU/word_phonemes.txt

# %%
# Phonemes that should stay together
grouped_phonemes = [
    "aa", "ai", "au", "dx", "ee", "eu", "ii", "lx", "nd", "ng", "nj", "nx",
    "rx", "sx", "tx", "oo", "uu", "zh"
]

# Function to split words into phonemes
def split_into_phonemes(word, grouped_phonemes):
    phonemes = []
    i = 0
    while i < len(word):
        # Check for grouped phonemes
        matched = False
        for phoneme in grouped_phonemes:
            if word[i:i+len(phoneme)] == phoneme:
                phonemes.append(phoneme)
                i += len(phoneme)
                matched = True
                break
        # If no grouped phoneme matched, add the single character
        if not matched:
            phonemes.append(word[i])
            i += 1
    return phonemes

# Input and Output File Paths
input_file = "/content/drive/Shareddrives/Audio_ processing/unique_words_200.txt"                       # <-------------- File containing the words to be processed --------------->
output_file = "/content/drive/Shareddrives/Audio_ processing/phone_output_200.txt"                      # <-------------- File to save the phoneme sequences ----------------->

# Read words from the input file
with open(input_file, "r") as infile:
    words = [line.strip() for line in infile.readlines()]

# Generate phoneme sequences for each word
results = []
for word in words:
    phoneme_sequence = split_into_phonemes(word, grouped_phonemes)
    results.append(f"{word}\t{' '.join(phoneme_sequence)}")

# Write the results to the output file
with open(output_file, "w") as outfile:
    for line in results:
        outfile.write(line + "\n")

print(f"Phoneme sequences written to {output_file}")
# Out:
# Phoneme sequences written to /content/drive/Shareddrives/Audio_ processing/phone_output_200.txt

# %% [markdown]
# # Audio normalization

# %%
import os
from pydub import AudioSegment
from pydub.effects import normalize

def normalize_audio_files(input_dir, output_dir):
    """
    Normalize audio files, including those in subfolders.

    Args:
        input_dir (str): Directory containing input audio files (including subfolders).
        output_dir (str): Directory to save normalized audio files, maintaining folder structure.
    """
    for root, dirs, files in os.walk(input_dir):  # Traverse all subdirectories
        for filename in files:
            if filename.endswith((".wav", ".mp3", ".flac", ".ogg")):  # Add other formats if needed
                input_path = os.path.join(root, filename)

                # Recreate the subfolder structure in the output directory
                relative_path = os.path.relpath(root, input_dir)
                output_subdir = os.path.join(output_dir, relative_path)
                if not os.path.exists(output_subdir):
                    os.makedirs(output_subdir)

                output_path = os.path.join(output_subdir, filename)

                try:
                    print(f"Processing: {input_path}")

                    # Load the audio file
                    audio = AudioSegment.from_file(input_path)

                    # Normalize the audio
                    normalized_audio = normalize(audio)

                    # Export the normalized audio to the output directory
                    normalized_audio.export(output_path, format="wav")  # Ensure output is in `.wav` format
                    print(f"Saved normalized file to: {output_path}")

                except Exception as e:
                    print(f"Error processing {input_path}: {e}")

# Set input and output directories
input_directory = "/content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech"
output_directory = "/content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised"

# Run the normalization
normalize_audio_files(input_directory, output_directory)
# Out:
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_1_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_1_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_2_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_2_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_3_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_3_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_4_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_4_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_5_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_5_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_6_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_6_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_7_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_7_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_8_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_8_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_9_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_9_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_10_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_10_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_11_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_11_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_12_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_12_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_13_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_13_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_14_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_14_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_15_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_15_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_16_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_16_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_17_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_17_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_18_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_18_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_19_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_19_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_20_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_20_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_1_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_1_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_2_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_2_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_3_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_3_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_4_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_4_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_5_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_5_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_6_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_6_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_7_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_7_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_8_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_8_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_9_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_9_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_10_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_10_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_11_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_11_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_12_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_12_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_13_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_13_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_14_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_14_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_16_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_16_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_17_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_17_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_18_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_18_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_19_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_19_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_20_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_20_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_1_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_1_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_2_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_2_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_3_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_3_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_4_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_4_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_5_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_5_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_6_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_6_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_7_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_7_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_8_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_8_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_9_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_9_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_10_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_10_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_11_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_11_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_12_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_12_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_13_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_13_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_14_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_14_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_15_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_15_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_16_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_16_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_17_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_17_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_18_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_18_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_19_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_19_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_20_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_20_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_1_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_1_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_2_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_2_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_3_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_3_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_4_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_4_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_5_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_5_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_7_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_7_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_6_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_6_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_8_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_8_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_9_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_9_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_10_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_10_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_11_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_11_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_12_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_12_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_13_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_13_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_14_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_14_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_15_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_15_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_16_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_16_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_17_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_17_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_18_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_18_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_19_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_19_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_20_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_20_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_1_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_1_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_2_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_2_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_3_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_3_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_4_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_4_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_5_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_5_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_6_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_6_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_7_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_7_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_8_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_8_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_9_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_9_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_10_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_10_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_11_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_11_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_12_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_12_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_13_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_13_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_14_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_14_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_17_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_17_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_18_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_18_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_19_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_19_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_20_5.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_20_5.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_1_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_1_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_2_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_2_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_3_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_3_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_4_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_4_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_5_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_5_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_6_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_6_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_7_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_7_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_8_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_8_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_9_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_9_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_10_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_10_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_11_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_11_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_12_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_12_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_13_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_13_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_14_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_14_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_15_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_15_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_16_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_16_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_17_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_17_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_18_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_18_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_19_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_19_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_20_6.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_20_6.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_1_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_1_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_2_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_2_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_3_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_3_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_4_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_4_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_5_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_5_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_6_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_6_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_7_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_7_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_8_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_8_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_9_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_9_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_10_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_10_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_11_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_11_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_12_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_12_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_13_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_13_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_14_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_14_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_15_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_15_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_16_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_16_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_17_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_17_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_18_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_18_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_19_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_19_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_20_7.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_20_7.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_1_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_1_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_2_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_2_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_3_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_3_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_5_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_5_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_4_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_4_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_6_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_6_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_7_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_7_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_8_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_8_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_9_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_9_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_10_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_10_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_11_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_11_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_12_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_12_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_13_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_13_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_14_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_14_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_15_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_15_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_16_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_16_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_17_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_17_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_18_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_18_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_19_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_19_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_20_8.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_20_8.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_1_9.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_1_9.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_1_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_1_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_3_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_3_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_4_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_4_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_5_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_5_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_6_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_6_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_7_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_7_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_8_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_8_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_9_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_9_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_10_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_10_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_11_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_11_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_12_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_12_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_13_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_13_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_14_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_14_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_15_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_15_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_16_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_16_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_17_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_17_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_18_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_18_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_19_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_19_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/1-20/MSU_20_10.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/1-20/MSU_20_10.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_21_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_21_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_22_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_22_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_23_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_23_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_24_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_24_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_25_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_25_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_26_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_26_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_27_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_27_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_28_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_28_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_29_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_29_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_30_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_30_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_31_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_31_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_32_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_32_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_33_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_33_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_34_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_34_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_35_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_35_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_36_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_36_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_37_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_37_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_38_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_38_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/21-40/MSU_39_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/21-40/MSU_39_1.wav
# ...
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_187_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_197_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_197_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_188_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_188_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_189_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_189_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_190_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_190_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_191_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_191_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_192_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_192_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_193_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_193_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_194_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_194_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_195_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_195_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_196_1.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_196_1.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_181_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_181_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_182_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_182_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_183_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_183_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_184_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_184_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_185_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_185_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_186_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_186_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_187_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_187_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_188_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_188_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_189_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_189_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_190_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_190_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_191_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_191_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_192_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_192_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_193_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_193_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_194_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_194_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_195_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_195_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_196_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_196_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_197_2.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_197_2.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_181_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_181_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_182_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_182_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_183_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_183_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_184_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_184_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_185_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_185_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_186_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_186_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_187_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_187_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_188_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_188_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_189_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_189_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_190_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_190_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_191_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_191_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_192_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_192_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_193_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_193_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_194_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_194_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_195_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_195_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_196_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_196_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_197_3.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_197_3.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_111_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_111_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_112_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_112_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_113_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_113_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_114_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_114_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_115_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_115_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_116_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_116_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_117_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_117_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_118_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_118_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_119_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_119_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_120_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_120_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_121_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_121_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_122_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_122_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_123_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_123_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_124_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_124_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_125_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_125_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_126_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_126_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_127_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_127_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_128_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_128_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_129_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_129_4.wav
# Processing: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech/test/MSU_130_4.wav
# Saved normalized file to: /content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/test/MSU_130_4.wav

# %% [markdown]
# ## Renaming speaker name of files

# %%
# prompt: i have files in sub dirs such as MSU_1_1.wav, MSU_2_1.wav so on i need to rename it as MSR_1_1.wav , MSR_2_1.wav..

import os
import re

def rename_files(root_dir):
    for subdir, _, files in os.walk(root_dir):
        for file in files:
            if file.startswith("MSU_") and file.endswith(".wav"):
                old_path = os.path.join(subdir, file)
                new_file = file.replace("MSU", "MSR", 1)
                new_path = os.path.join(subdir, new_file)
                os.rename(old_path, new_path)
                # print(f"Renamed '{old_path}' to '{new_path}'")
        print("All files renamed successfully.")

# Example usage (replace with your actual directory)
root_directory = "/content/drive/Shareddrives/Audio_ processing/Segmented_data/Suradha_MSR/speech_normalised/"   # <------------------ Path to directory containing files --------------------->
rename_files(root_directory)
# Out:
# All files renamed successfully.
# All files renamed successfully.
# All files renamed successfully.
# All files renamed successfully.
# All files renamed successfully.
# All files renamed successfully.
# All files renamed successfully.
# All files renamed successfully.
# All files renamed successfully.

# %% [markdown]
# # MISC

# %%
with open('/content/41-60(1).lab','r') as f:
  lines = f.readlines()

lines[1::2]
# Out:
# ['45800000 73875000 41\n',
#  '84300000 99725000 42\n',
#  '119475000 152550000 43\n',
#  '188000000 227850000 44\n',
#  '256400000 284550000 45\n',
#  '342125000 385500000 46\n',
#  '438900000 472625000 47\n',
#  '698350000 746800000 48\n',
#  '806025000 823900000 49\n',
#  '877125000 877150000 50\n',
#  '914375000 943100000 51\n',
#  '1080575000 1121275000 53\n',
#  '1163100000 1203050000 54\n',
#  '1250200000 1293700000 55\n',
#  '1346825000 1385125000 56\n',
#  '1415900000 1445600000 57\n',
#  '1605175000 1638225000 59\n']

# %%
# prompt: given start and end times, use pydub for audio segmentation. The resulting wav should be in .wav

from pydub import AudioSegment

# Replace with your actual file paths and desired start and end times
audio_file = "/content/41-60(1).wav"

count= 0

for line in lines[1::2]:
  count+=1
  start_time, end_time = line.split(' ')[0:2]
  start_time_ms = float(start_time)/10000  # Start time in milliseconds
  end_time_ms = float(end_time)/10000    # End time in milliseconds

  audio = AudioSegment.from_file(audio_file)
  extracted_audio = audio[start_time_ms:end_time_ms]

  output_file = "FGA"+str(count)+"_1.wav"
  extracted_audio.export(output_file, format="wav")

# %%
import os

# Replace with your actual file paths and desired start and end times
audio_file = "/content/drive/Shareddrives/NIEPMD DATA COLLECTION/Data collection _ Annotation/Data/Suradha(MSU)/Speech/1-20/1-20(1).wav"

count= 1

for line in lines[1::2]:
  start_time, end_time = line.split(' ')[0:2]
  start_time_ms = float(start_time)/10000  # Start time in milliseconds
  end_time_ms = float(end_time)/10000    # End time in milliseconds

  audio = AudioSegment.from_file(audio_file)
  extracted_audio = audio[start_time_ms:end_time_ms]

  output_file = "/content/drive/Shareddrives/Audio_ processing/Segmented_data/MSU/MSU_"+str(count)+"_1.wav"
  os.makedirs(os.path.dirname(output_file), exist_ok=True)
  extracted_audio.export(output_file, format="wav")
  count+=1
print("done")
# Out:
# done

# %%
import IPython.display as ipd

ipd.Audio('/content/drive/Shareddrives/Audio_ processing/Segmented_data/FGA/FGA41_1.wav')

# %%
# prompt: how do we store the extracted audio files in drive
# !pip install pydub
from pydub import AudioSegment
import IPython.display as ipd
with open('/content/drive/Shareddrives/Audio_ processing/Segmented_data/MSU/label/131-155/131-155(4).lab','r') as f:
  lines = f.readlines()

lines=lines[1::2]

# lines=lines[16::2]



print('no of sentences : ', len(lines))

lines
# Out:
# no of sentences :  25
# ['31375000 54100000 131\n',
#  '55575000 77050000 132\n',
#  '77900000 101950000 133\n',
#  '102250000 126675000 134\n',
#  '127775000 165675000 135\n',
#  '167200000 195450000 136\n',
#  '206600000 220825000 137\n',
#  '222025000 235575000 138\n',
#  '254750000 275950000 139\n',
#  '277050000 298175000 140\n',
#  '298950000 313600000 141\n',
#  '314825000 335325000 142\n',
#  '337275000 369275000 143\n',
#  '391000000 417875000 144\n',
#  '419575000 437850000 145\n',
#  '438825000 472100000 146\n',
#  '501025000 519550000 147\n',
#  '520925000 541950000 148\n',
#  '543250000 557150000 150\n',
#  '573075000 587450000 149\n',
#  '605025000 630750000 151\n',
#  '631900000 655050000 152\n',
#  '697225000 732725000 153\n',
#  '733875000 777825000 154\n',
#  '795600000 824500000 155\n']
